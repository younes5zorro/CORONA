# %%
import pandas as pd

dialectid_data=pd.read_csv('dialectid_data.tsv',delimiter='\t',encoding='utf-8',error_bad_lines=False)
dialectid_data.head()
# Out:
# b'Skipping line 3614: expected 100 fields, saw 198\nSkipping line 4409: expected 100 fields, saw 261\nSkipping line 5538: expected 100 fields, saw 128\n'
# b'Skipping line 11961: expected 100 fields, saw 149\n'
# b'Skipping line 17152: expected 100 fields, saw 156\nSkipping line 18905: expected 100 fields, saw 156\nSkipping line 20153: expected 100 fields, saw 226\nSkipping line 20339: expected 100 fields, saw 191\nSkipping line 21632: expected 100 fields, saw 184\nSkipping line 22369: expected 100 fields, saw 135\n'
# b'Skipping line 27563: expected 100 fields, saw 156\nSkipping line 31331: expected 100 fields, saw 149\nSkipping line 31422: expected 100 fields, saw 121\n'
# C:\Users\youne\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# ...

# %%
dialectid_data.shape
# Out:
# (32946, 100)

# %%
dialectid_data.iloc[4]
# Out:
# HIT_info                        DialectClassification#batch:2#HIT:2
# HIT-ID                               1K5AL9D8FTJLVLOFRSAFJGESLELWJZ
# AID                                                  A30D509B0ZC9DQ
# AssignmentID                         1R7LE5LUEC958U8TCZ9GLKHDV4P4P3
# HITStatus                                                  Approved
# WorkerIP                                              86.108.41.212
# WorkerCountry                                                Jordan
# WorkerCity                                                    Amman
# country_live                                                 jordan
# native_arabic                                                   Yes
# native_dialect                                            levantine
# years_speaking                                                   27
# StartTime_str                          Sun Dec 12 13:43:30 EET 2010
# EndTime_str                            Sun Dec 12 13:49:24 EET 2010
# ...

# %%
dialectid_data['Sentence12'][4]
# Out:
# 'فيها ايه اما نفتح الحدود ونحول منطقه رفح المصريه لمنطقه تجاره حره بينا وبين غزه'

# %%
dialectid_data['DClass12'][4]
# Out:
# 'egyptian'

# %%
dialectid_data.filter(regex=("DClass.*"))
# Out:
#          DClass1    DClass2    DClass3    DClass4    DClass5    DClass6  \
# 0            NaN        NaN       gulf        NaN  levantine  levantine
# 1            NaN        NaN       gulf        NaN  levantine   egyptian
# 2            NaN        NaN        NaN        NaN       gulf        NaN
# 3            NaN        NaN        NaN   egyptian       gulf       gulf
# 4        general        NaN        NaN    general       gulf        NaN
# 5            NaN        NaN    general   egyptian  levantine        NaN
# 6        general        NaN        NaN        NaN        NaN       gulf
# 7        general        NaN        NaN    general        NaN       gulf
# 8       egyptian        NaN        NaN        NaN        NaN   maghrebi
# 9        general        NaN  levantine        NaN        NaN       gulf
# 10          gulf        NaN  levantine        NaN        NaN       gulf
# 11       general        NaN    general        NaN        NaN       gulf
# ...

# %%
dialectid_data.DClass11.unique()
# Out:
# array(['general', 'egyptian', nan, 'levantine', 'gulf', 'maghrebi',
#        'notsure', 'iraqi', 'other', 'prompt'], dtype=object)
